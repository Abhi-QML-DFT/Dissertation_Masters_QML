# %%
### Import packages
import sys, getopt, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler #StandardScaler is sensitive to outlier

from qiskit.circuit.library import PauliFeatureMap, RealAmplitudes, ZZFeatureMap
from qiskit_machine_learning.algorithms import VQR
from qiskit_algorithms.optimizers import L_BFGS_B

# %%
#Instead of ;
# *FEATURE_MAP_REPS_LIST = [1,2,3,4,5], *ANSATZ_REPS_LIST = [1,2,3,4,5], *N_REPEATS = 10
# I used ;
# *FEATURE_MAP_REPS_LIST = [1] , *ANSATZ_REPS_LIST = [1], *N_REPEATS = 1
# to reduce the number of experiments.

# %%
root_folder = 'VQR'
### Globals
# For reproducibility
np.random.seed(42)

# Fixed feature sizes
NUM_FEATURES = 3

# Quantum circuit parameters
IF_PAULI_FEATURE_MAP_LIST = [True, False]
FEATURE_MAP_REPS_LIST = [1]
ANSATZ_REPS_LIST = [1]
ENTANGLEMENT_LIST = ['linear', 'full', 'circular']

# Training hyperparameters
LOSS_FUNCTION = 'squared_error'

# K-fold cross-validation parameters
N_REPEATS = 1
TEST_SIZE = 1

# %%
#Preparing the dataset for k-fold cross-validation

def prepare_dataset_k_fold(X, y, train_indices, test_indices):
    # Separate train/test split
    X_train_raw, X_test_raw = X[train_indices], X[test_indices]
    y_train, y_test = y[train_indices], y[test_indices]

    # Separate element column from the actual features
    element_test = X_test_raw[:, 0]
    element_train = X_train_raw[:, 0]

    # Drop the element column (first column)
    X_train = X_train_raw[:, 1:]
    X_test = X_test_raw[:, 1:]

    full_X = np.vstack([X_train, X_test])

    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(full_X)

    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    return X_train_scaled, y_train, X_test_scaled, y_test, element_test, element_train

# %%
#Quantum kernel builder

def reconfig_quantum_kernel_vqr(if_pauli_feature_map, feature_reps, ansatz_reps, entangle, objective_func_vals):
    """
        Create a quantum kernel
        vqr = VQR(C=20.0, epsilon=0.2, quantum_kernel=kernel)

        Args:
            if_pauli_feature_map: If True, use a Pauli feature map, else ZZ feature map.
            feature_reps: Number of repetitions of quantum circuit for a feature map.
            ansatz_reps: Number of repetitions of quantum circuit for the ansatz.
            entangle: Entanglement type of the feature map.
            objective_func_vals: List to store the objective function values during training.

        Returns:
            vqr: quantum kernel
    """
    # Define callback function for plotting the training progress
    def callback_graph(weights, obj_func_eval):
        # clear_output(wait=True)
        objective_func_vals.append(obj_func_eval)
        print(f"Iteration: {len(objective_func_vals)}, Objective function value: {obj_func_eval}")
        #plt.rcParams["figure.figsize"] = (12, 6)
        #plt.xlabel("Iteration")
        #plt.ylabel("Objective function value")
        #plt.plot(range(len(objective_func_vals)), objective_func_vals)
        #plt.show()

    # Configure feature map
    if if_pauli_feature_map:
        feature_map = PauliFeatureMap(feature_dimension=NUM_FEATURES, reps=feature_reps, entanglement=entangle)
    else:
        feature_map = ZZFeatureMap(feature_dimension=NUM_FEATURES, reps=feature_reps, entanglement=entangle)

    # Configure ansatz
    ansatz = RealAmplitudes(num_qubits=NUM_FEATURES, reps=ansatz_reps)

    # Configure optimizer
    optimizer = L_BFGS_B(ftol=0.000001)

    return VQR(feature_map=feature_map,
               ansatz=ansatz,
               optimizer=optimizer,
               callback=callback_graph,
               loss=LOSS_FUNCTION,
               )

# %%
#Training function

def train_vqr(vqr, X_train, y_train, X_test):
    """
        Train based on X_train/y_train (after scaling), return prediction from X_test

        Args:
            vqr: quantum kernel
            X_train:
            y_train
            X_test

        Returns:
    """
    vqr.fit(X_train, np.concatenate(y_train))
    return vqr.predict(X_train), vqr.predict(X_test)

# %%
#Command line argument parser

def get_arguments(argvs):
    _entangle = ''
    _feature_map_reps = ''
    _ansatz_reps = ''
    _if_pauli_feature = True
    try:
        opts, args = getopt.getopt(argvs, "h:e:f:a:p:", ["entangle=", "feature_map_reps=", "ansatz_reps=", "if_pauli_feature="])
    except getopt.GetoptError:
        print(root_folder + '.py -e <entangle> -f <feature_map_reps> -a <ansatz_reps> -p <if_pauli_feature>')
        sys.exit(2)
    for opt, arg in opts:
        if opt == '-h':
            print(root_folder + '.py -e <entangle> -f <feature_map_reps> -a <ansatz_reps> -p <if_pauli_feature>')
            sys.exit()
        elif opt in ("-e", "--entangle"):
            _entangle = arg
        elif opt in ("-f", "--feature_map_reps"):
            _feature_map_reps = int(arg)
        elif opt in ("-a", "--ansatz_reps"):
            _ansatz_reps = int(arg)
        elif opt in ("-p", "--if_pauli_feature"):
            _if_pauli_feature = eval(arg)
    return _entangle, _feature_map_reps, _ansatz_reps, _if_pauli_feature

# %%
#output folder
date = '05_31_25_0'

if not os.path.exists(f'{root_folder}/result'):
    os.makedirs(f'{root_folder}/result')
if not os.path.exists(f'{root_folder}/logs'):
    os.makedirs(f'{root_folder}/logs')

# %%
#Load dataset

dataset_name = "/home/ashok/Desktop/ABHI/Learning,Reproducing/qml_training-validation-data.csv"
df = pd.read_csv(dataset_name)
display(df.head)
X = df[['Element', 'el_neg', 'B/GPa', 'Volume/A^3']].values
y = df['SFE/mJm^-3'].values
print(df.shape)
# Out:
# <bound method NDFrame.head of    Element  el_neg  B/GPa  Volume/A^3  SFE/mJm^-3
# 0       Be    1.57  130.0        8.09       23.48
# 1       Sc    1.36   57.0       25.00       16.16
# 2       Ti    1.54  110.0       17.60       24.44
# 3       Co    1.88  180.0       11.00       37.64
# 4       Zn    1.65   70.0       15.20       20.98
# 5        Y    1.22   41.0       33.00        8.52
# 6       Zr    1.33   91.1       23.30       22.18
# 7       Tc    1.90  281.0       14.20       36.19
# 8       Ru    2.20  220.0       13.60       40.50
# 9       Pr    1.13   29.0       35.30        1.65
# 10      Nd    1.14   32.0       34.20        0.25
# 11      Gd    1.20   38.0       33.10        5.20
# 12      Tb    1.20   38.7       32.10        6.17
# 13      Dy    1.22   41.0       31.60        7.06
# 14      Ho    1.23   40.0       31.20        7.82
# 15      Er    1.24   44.0       30.60        8.45
# 16      Tm    1.25   45.0       30.10        8.96
# 17      Lu    1.27   48.0       29.50        9.75
# 18      Re    1.90  370.0       14.70       35.35
# 19      Os    2.20  462.0       14.00       38.54
# 20      Tl    1.62   43.0       28.70       22.09>
# (21, 5)

# %%
#Scale the target variable y to the range [-1, 1] using MinMaxScaler

y_scaler = MinMaxScaler(feature_range=(-1, 1))
y = y_scaler.fit_transform(y.reshape(-1, 1))

# %%
print('Total number of data: ', X.shape[0])
rkf = RepeatedKFold(n_splits=X.shape[0] // TEST_SIZE, n_repeats=N_REPEATS)
print(rkf)
# Out:
# Total number of data:  21
# RepeatedKFold(n_repeats=1, n_splits=21, random_state=None)

# %%
#Results dataframe

df = pd.DataFrame(columns=['feature_map_name', 'feature_map_reps', 'ansatz_reps', 'entanglement',
                               'element test', 'actual test', 'predicted test',
                               'element train', 'actual train', 'predicted train',
                               'R2 test', 'R2 train'])

# %%
if len(FEATURE_MAP_REPS_LIST) == 1:
    FEATURE_MAP_REPS_LIST_NAME = FEATURE_MAP_REPS_LIST[0]
else:
    FEATURE_MAP_REPS_LIST_NAME = FEATURE_MAP_REPS_LIST
if len(ANSATZ_REPS_LIST) == 1:
     ANSATZ_REPS_LIST_NAME = ANSATZ_REPS_LIST[0]
else:
    ANSATZ_REPS_LIST_NAME = ANSATZ_REPS_LIST
if len(ENTANGLEMENT_LIST) == 1:
    ENTANGLEMENT_LIST_NAME = ENTANGLEMENT_LIST[0]
else:
    ENTANGLEMENT_LIST_NAME = ENTANGLEMENT_LIST
if len(IF_PAULI_FEATURE_MAP_LIST) == 1:
    IF_PAULI_FEATURE_MAP_LIST_NAME = IF_PAULI_FEATURE_MAP_LIST[0]
else:
    IF_PAULI_FEATURE_MAP_LIST_NAME = IF_PAULI_FEATURE_MAP_LIST
IF_PAULI_FEATURE_MAP_LIST_NAME = str(IF_PAULI_FEATURE_MAP_LIST_NAME).replace('False', 'ZZ').replace('True', 'Pauli')
file_name = f'{root_folder}/result/FMR_{FEATURE_MAP_REPS_LIST_NAME}_AR_{ANSATZ_REPS_LIST_NAME}_E_{ENTANGLEMENT_LIST_NAME}_P_{IF_PAULI_FEATURE_MAP_LIST_NAME}_{date}.csv'
print('\nTo be saved to', file_name)
# Out:
# To be saved to VQR/result/FMR_1_AR_1_E_['linear', 'full', 'circular']_P_[Pauli, ZZ]_05_31_25_0.csv

# %%
i = 0

print("\n--- Start K-Fold Loop ---")

for train_indices, test_indices in rkf.split(X):
    X_train, y_train, X_test, y_test, element_test, element_train = prepare_dataset_k_fold(X, y, train_indices, test_indices)
    for if_pauli_feature_map in IF_PAULI_FEATURE_MAP_LIST:
        for feature_map_reps in FEATURE_MAP_REPS_LIST:
            for ansatz_reps in ANSATZ_REPS_LIST:
                for entanglement in ENTANGLEMENT_LIST:
                    if if_pauli_feature_map:
                        feature_map_name = 'Pauli'
                    else:
                        feature_map_name = 'ZZ'
                    print(f'\nfeature_map_name:{feature_map_name} '
                            f'feature_map_reps:{feature_map_reps} '
                            f'ansatz_reps:{ansatz_reps} '
                            f'entanglement:{entanglement} '
                            f'element test:{element_test[0]} ')
                    # conf kernel
                    objective_func_vals = []
                    vqr = reconfig_quantum_kernel_vqr(if_pauli_feature_map=if_pauli_feature_map,
                                                        feature_reps=feature_map_reps,
                                                        ansatz_reps=ansatz_reps,
                                                        entangle=entanglement,
                                                        objective_func_vals=objective_func_vals,
                                                        )

                    # train
                    predict_train, predict_test = train_vqr(vqr, X_train, y_train, X_test)

                    # some conversions
                    all_preds = np.array(predict_test)
                    all_targets = np.array(y_test)
                    all_preds = y_scaler.inverse_transform(all_preds.reshape(-1, 1))
                    all_targets = y_scaler.inverse_transform(all_targets.reshape(-1, 1))

                    all_preds_train = np.array(predict_train)
                    all_targets_train = np.array(y_train)
                    all_preds_train = y_scaler.inverse_transform(all_preds_train.reshape(-1, 1))
                    all_targets_train = y_scaler.inverse_transform(all_targets_train.reshape(-1, 1))

                    # save data
                    new_row = {'feature_map_name': feature_map_name,
                                'feature_map_reps': feature_map_reps,
                                'ansatz_reps': ansatz_reps,
                                'entanglement': entanglement,
                                'element test': element_test,
                                'actual test': np.array(all_targets).flatten(),
                                'predicted test': np.array(all_preds).flatten(),
                                'element train': element_train,
                                'actual train': np.array(all_targets_train).flatten(),
                                'predicted train': np.array(all_preds_train).flatten(),
                                #'R2 test': r2_score(y_test, predict_test),
                                'R2 train': r2_score(y_train, predict_train),
                                }
                    df.loc[len(df)] = new_row
                    with np.printoptions(linewidth=10000):
                        df.to_csv(file_name, index=False)  # update csv every loop
                    df.at[0, "info"] = [f"DATASET: {dataset_name}, LOSS: {LOSS_FUNCTION}"]
                    i += 1
# Out:
# --- Start K-Fold Loop ---
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Be
# Iteration: 1, Objective function value: 0.6207607510917652
# Iteration: 2, Objective function value: 0.3479242077417568
# Iteration: 3, Objective function value: 0.2917391302034078
# Iteration: 4, Objective function value: 0.4656126336836591
# Iteration: 5, Objective function value: 0.24079355837692257
# Iteration: 6, Objective function value: 0.2099610619399467
# Iteration: 7, Objective function value: 0.20700076037912102
# Iteration: 8, Objective function value: 0.20363961728842236
# Iteration: 9, Objective function value: 0.2016452910412932
# Iteration: 10, Objective function value: 0.19733918408865342
# Iteration: 11, Objective function value: 0.1939535626818449
# Iteration: 12, Objective function value: 0.18758011723833676
# Iteration: 13, Objective function value: 0.17675928325503526
# Iteration: 14, Objective function value: 0.17238828478861373
# Iteration: 15, Objective function value: 0.16678348691086858
# Iteration: 16, Objective function value: 0.2398262172927031
# Iteration: 17, Objective function value: 0.15431863827287076
# Iteration: 18, Objective function value: 0.1517299007888978
# Iteration: 19, Objective function value: 0.15139193328125714
# Iteration: 20, Objective function value: 0.1512762377478519
# Iteration: 21, Objective function value: 0.15121016653339672
# Iteration: 22, Objective function value: 0.1512159175054253
# Iteration: 23, Objective function value: 0.1511898699341069
# Iteration: 24, Objective function value: 0.15117762075942803
# Iteration: 25, Objective function value: 0.1511769606759192
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Be
# Iteration: 1, Objective function value: 0.7014266138414496
# Iteration: 2, Objective function value: 0.453070895553709
# Iteration: 3, Objective function value: 0.8823356723028667
# Iteration: 4, Objective function value: 0.3843979727556355
# Iteration: 5, Objective function value: 0.30769819919855984
# Iteration: 6, Objective function value: 0.2988494893040091
# Iteration: 7, Objective function value: 0.24199003179381368
# Iteration: 8, Objective function value: 0.23765738455011004
# Iteration: 9, Objective function value: 0.23441137492037947
# Iteration: 10, Objective function value: 0.2329509026981947
# Iteration: 11, Objective function value: 0.22965551455613195
# Iteration: 12, Objective function value: 0.2262331053288269
# Iteration: 13, Objective function value: 0.21374798282124083
# Iteration: 14, Objective function value: 0.45823752631927384
# Iteration: 15, Objective function value: 0.19764015413651517
# Iteration: 16, Objective function value: 0.19085817192428928
# Iteration: 17, Objective function value: 0.7446931031657742
# Iteration: 18, Objective function value: 0.318642398828993
# Iteration: 19, Objective function value: 0.18968708955595803
# Iteration: 20, Objective function value: 0.20068640320592931
# Iteration: 21, Objective function value: 0.18725432939151881
# Iteration: 22, Objective function value: 0.17926755903329358
# Iteration: 23, Objective function value: 0.16414894976308966
# Iteration: 24, Objective function value: 0.1637287958492064
# Iteration: 25, Objective function value: 0.16323774677965736
# Iteration: 26, Objective function value: 0.16269061515875183
# Iteration: 27, Objective function value: 0.16255153564982222
# Iteration: 28, Objective function value: 0.1624168175775329
# Iteration: 29, Objective function value: 0.16240127636524962
# Iteration: 30, Objective function value: 0.16239836846113112
# Iteration: 31, Objective function value: 0.16238415836287926
# Iteration: 32, Objective function value: 0.16237036439024513
# Iteration: 33, Objective function value: 0.16235586698662927
# Iteration: 34, Objective function value: 0.16236586318144347
# Iteration: 35, Objective function value: 0.16234896018225764
# Iteration: 36, Objective function value: 0.16234536827557516
# Iteration: 37, Objective function value: 0.1623449074289242
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Be
# Iteration: 1, Objective function value: 0.7806755196219559
# Iteration: 2, Objective function value: 0.37595237366207057
# Iteration: 3, Objective function value: 0.8170293311397625
# Iteration: 4, Objective function value: 0.26717277082716023
# Iteration: 5, Objective function value: 0.2259972064110601
# Iteration: 6, Objective function value: 0.19706672871971903
# Iteration: 7, Objective function value: 0.1802177699657817
# Iteration: 8, Objective function value: 0.17375066463526959
# Iteration: 9, Objective function value: 0.1727236976719194
# Iteration: 10, Objective function value: 0.1697891069508201
# Iteration: 11, Objective function value: 0.1670776524884286
# Iteration: 12, Objective function value: 0.16518746265283143
# Iteration: 13, Objective function value: 0.16415835971910198
# Iteration: 14, Objective function value: 0.16473222424140754
# Iteration: 15, Objective function value: 0.16390594649487988
# Iteration: 16, Objective function value: 0.16370526806821434
# Iteration: 17, Objective function value: 0.16368564153064244
# Iteration: 18, Objective function value: 0.16363164322614135
# Iteration: 19, Objective function value: 0.16318530386562172
# Iteration: 20, Objective function value: 0.16516524799322146
# Iteration: 21, Objective function value: 0.16310552619369093
# Iteration: 22, Objective function value: 0.1628101555139615
# Iteration: 23, Objective function value: 0.16265382121708094
# Iteration: 24, Objective function value: 0.16244144969218394
# Iteration: 25, Objective function value: 0.16237645445286036
# Iteration: 26, Objective function value: 0.1623474222348249
# Iteration: 27, Objective function value: 0.16234503322942823
# Iteration: 28, Objective function value: 0.16234490223727988
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Be
# Iteration: 1, Objective function value: 0.565053054815426
# Iteration: 2, Objective function value: 0.28139078835181064
# Iteration: 3, Objective function value: 0.3032318986993
# Iteration: 4, Objective function value: 0.2513750018319659
# Iteration: 5, Objective function value: 0.24474879710397382
# Iteration: 6, Objective function value: 0.23122116789769082
# Iteration: 7, Objective function value: 0.2121158623658343
# Iteration: 8, Objective function value: 0.14525082268455616
# Iteration: 9, Objective function value: 0.34129130238317607
# Iteration: 10, Objective function value: 0.13967881564779036
# Iteration: 11, Objective function value: 0.12820285975559428
# Iteration: 12, Objective function value: 0.1268975289160919
# Iteration: 13, Objective function value: 0.12663391265631335
# Iteration: 14, Objective function value: 0.12655830474314197
# Iteration: 15, Objective function value: 0.12622540969389992
# Iteration: 16, Objective function value: 0.12593514786595544
# Iteration: 17, Objective function value: 0.12569364797201935
# Iteration: 18, Objective function value: 0.12568530208720927
# Iteration: 19, Objective function value: 0.12566100247747292
# Iteration: 20, Objective function value: 0.12566049049726588
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Be
# Iteration: 1, Objective function value: 0.6793423888642075
# Iteration: 2, Objective function value: 0.35357533811974506
# Iteration: 3, Objective function value: 0.6619834495511819
# Iteration: 4, Objective function value: 0.2977082647176771
# Iteration: 5, Objective function value: 0.27541095540845645
# Iteration: 6, Objective function value: 0.24053303273208604
# Iteration: 7, Objective function value: 0.20641357748624345
# Iteration: 8, Objective function value: 0.17640197281488576
# Iteration: 9, Objective function value: 0.16919484579167618
# Iteration: 10, Objective function value: 0.16495065523811303
# Iteration: 11, Objective function value: 0.16415622708055128
# Iteration: 12, Objective function value: 0.16374355670604207
# Iteration: 13, Objective function value: 0.16348794002641953
# Iteration: 14, Objective function value: 0.16302426797617867
# Iteration: 15, Objective function value: 0.16276518269906598
# Iteration: 16, Objective function value: 0.1626370706517114
# Iteration: 17, Objective function value: 0.16257240982301263
# Iteration: 18, Objective function value: 0.16244660840508124
# Iteration: 19, Objective function value: 0.162442767752877
# Iteration: 20, Objective function value: 0.16241381444530537
# Iteration: 21, Objective function value: 0.16235102623437944
# Iteration: 22, Objective function value: 0.16234499175686623
# Iteration: 23, Objective function value: 0.1623449071315229
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Be
# Iteration: 1, Objective function value: 0.5010083296352754
# Iteration: 2, Objective function value: 0.33238780382522776
# Iteration: 3, Objective function value: 0.3119250026315715
# Iteration: 4, Objective function value: 0.27496133131082495
# Iteration: 5, Objective function value: 0.5093913865903916
# Iteration: 6, Objective function value: 0.26233686205523526
# Iteration: 7, Objective function value: 0.2536338476783332
# Iteration: 8, Objective function value: 0.24291565086892208
# Iteration: 9, Objective function value: 0.23453501405201646
# Iteration: 10, Objective function value: 0.23031550093261371
# Iteration: 11, Objective function value: 0.22498926724559087
# Iteration: 12, Objective function value: 0.2398668341404327
# Iteration: 13, Objective function value: 0.21416019330733552
# Iteration: 14, Objective function value: 0.21338639283073393
# Iteration: 15, Objective function value: 0.2124121251098085
# Iteration: 16, Objective function value: 1.0184395138624969
# Iteration: 17, Objective function value: 0.21200615142730067
# Iteration: 18, Objective function value: 0.2008124555683045
# Iteration: 19, Objective function value: 0.1859976978662533
# Iteration: 20, Objective function value: 0.16489366442016362
# Iteration: 21, Objective function value: 0.16437849927891438
# Iteration: 22, Objective function value: 0.1634947588756773
# Iteration: 23, Objective function value: 0.16326576265345202
# Iteration: 24, Objective function value: 0.16258062563386638
# Iteration: 25, Objective function value: 0.16242715046647932
# Iteration: 26, Objective function value: 0.16236330732646506
# Iteration: 27, Objective function value: 0.16234509056715127
# Iteration: 28, Objective function value: 0.162344971303176
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Lu
# Iteration: 1, Objective function value: 0.6758318763453344
# Iteration: 2, Objective function value: 0.4201517544208756
# Iteration: 3, Objective function value: 0.7192103043246589
# Iteration: 4, Objective function value: 0.17828316699344932
# Iteration: 5, Objective function value: 0.583303969577935
# Iteration: 6, Objective function value: 0.14336199608478178
# Iteration: 7, Objective function value: 0.12652993292302595
# Iteration: 8, Objective function value: 0.12416266971756273
# Iteration: 9, Objective function value: 0.12309638491614805
# Iteration: 10, Objective function value: 0.12296614721891155
# Iteration: 11, Objective function value: 0.122878702158939
# Iteration: 12, Objective function value: 0.12194849570456331
# Iteration: 13, Objective function value: 0.12769860175596986
# Iteration: 14, Objective function value: 0.12073015460207892
# Iteration: 15, Objective function value: 0.12005155485441572
# Iteration: 16, Objective function value: 0.11912861874814593
# Iteration: 17, Objective function value: 0.11796661045209297
# Iteration: 18, Objective function value: 0.11721891510898041
# Iteration: 19, Objective function value: 0.11708898816019686
# Iteration: 20, Objective function value: 0.11676732720831659
# Iteration: 21, Objective function value: 0.11624284972965418
# Iteration: 22, Objective function value: 0.1156042283884378
# Iteration: 23, Objective function value: 0.11507031365083756
# Iteration: 24, Objective function value: 0.11493622639368246
# Iteration: 25, Objective function value: 0.11496571470184436
# Iteration: 26, Objective function value: 0.11491201443792083
# Iteration: 27, Objective function value: 0.11490887540638821
# Iteration: 28, Objective function value: 0.11490547897052679
# Iteration: 29, Objective function value: 0.11490546728408221
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Lu
# Iteration: 1, Objective function value: 0.6629277986504705
# Iteration: 2, Objective function value: 0.3170239317612687
# Iteration: 3, Objective function value: 0.2642956315216822
# Iteration: 4, Objective function value: 0.24136135590763388
# Iteration: 5, Objective function value: 0.192009523683151
# Iteration: 6, Objective function value: 0.192206537199786
# Iteration: 7, Objective function value: 0.1837537598146335
# Iteration: 8, Objective function value: 0.17823350167554583
# Iteration: 9, Objective function value: 0.18070488935169177
# Iteration: 10, Objective function value: 0.17458634813400448
# Iteration: 11, Objective function value: 0.1718223699606838
# Iteration: 12, Objective function value: 0.17036068179145053
# Iteration: 13, Objective function value: 0.16716984600970827
# Iteration: 14, Objective function value: 0.16468568799928793
# Iteration: 15, Objective function value: 0.16176833139939323
# Iteration: 16, Objective function value: 0.15930172812924243
# Iteration: 17, Objective function value: 0.15802365096311444
# Iteration: 18, Objective function value: 0.15776230636683644
# Iteration: 19, Objective function value: 0.15768920650916787
# Iteration: 20, Objective function value: 0.15767153739872453
# Iteration: 21, Objective function value: 0.1576679358282248
# Iteration: 22, Objective function value: 0.15766059623262674
# Iteration: 23, Objective function value: 0.15764537578850538
# Iteration: 24, Objective function value: 0.15764014010607452
# Iteration: 25, Objective function value: 0.15763959031582034
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Lu
# Iteration: 1, Objective function value: 0.5796211812267142
# Iteration: 2, Objective function value: 0.3922703483668242
# Iteration: 3, Objective function value: 0.3018819476453335
# Iteration: 4, Objective function value: 0.33425094807332645
# Iteration: 5, Objective function value: 0.2775417825554426
# Iteration: 6, Objective function value: 0.25350309338994953
# Iteration: 7, Objective function value: 0.24014229534793516
# Iteration: 8, Objective function value: 0.23013669777822074
# Iteration: 9, Objective function value: 0.22717895650375192
# Iteration: 10, Objective function value: 0.2235415916488311
# Iteration: 11, Objective function value: 0.22979915666417652
# Iteration: 12, Objective function value: 0.2184372630696839
# Iteration: 13, Objective function value: 0.7430098534144226
# Iteration: 14, Objective function value: 0.21769505598893102
# Iteration: 15, Objective function value: 0.266057403352174
# Iteration: 16, Objective function value: 0.21086482646572868
# Iteration: 17, Objective function value: 0.23196656640757757
# Iteration: 18, Objective function value: 0.20453947875763276
# Iteration: 19, Objective function value: 0.18633925316005
# Iteration: 20, Objective function value: 0.17185646747886266
# Iteration: 21, Objective function value: 0.16683462115472925
# Iteration: 22, Objective function value: 0.1651102569522187
# Iteration: 23, Objective function value: 0.1617881464697674
# Iteration: 24, Objective function value: 0.15907262286939833
# Iteration: 25, Objective function value: 0.15794344100423957
# Iteration: 26, Objective function value: 0.1578872008050803
# Iteration: 27, Objective function value: 0.15785959267894392
# Iteration: 28, Objective function value: 0.157818045660756
# Iteration: 29, Objective function value: 0.15776090885281
# Iteration: 30, Objective function value: 0.15770115397340434
# Iteration: 31, Objective function value: 0.15764570631414027
# Iteration: 32, Objective function value: 0.15763945428066287
# Iteration: 33, Objective function value: 0.1576393832934629
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Lu
# Iteration: 1, Objective function value: 0.559640416046808
# Iteration: 2, Objective function value: 0.2887359733334724
# Iteration: 3, Objective function value: 0.203802388898352
# Iteration: 4, Objective function value: 0.15627916266436898
# Iteration: 5, Objective function value: 0.1360348683851445
# Iteration: 6, Objective function value: 0.12545397670277486
# Iteration: 7, Objective function value: 0.12425098433254675
# Iteration: 8, Objective function value: 0.12402153232361868
# Iteration: 9, Objective function value: 0.12398918757949488
# Iteration: 10, Objective function value: 0.12394470836983591
# Iteration: 11, Objective function value: 0.12380627724269758
# Iteration: 12, Objective function value: 0.12257130366766933
# Iteration: 13, Objective function value: 0.15104629330342126
# Iteration: 14, Objective function value: 0.12139601343070168
# Iteration: 15, Objective function value: 0.8428879359195403
# Iteration: 16, Objective function value: 0.12137199188567979
# Iteration: 17, Objective function value: 0.12120799309404622
# Iteration: 18, Objective function value: 0.12020076346748645
# Iteration: 19, Objective function value: 0.11786588548921226
# Iteration: 20, Objective function value: 0.11685997065104345
# Iteration: 21, Objective function value: 0.11551629548434508
# Iteration: 22, Objective function value: 0.11540166930860248
# Iteration: 23, Objective function value: 0.11491829496727728
# Iteration: 24, Objective function value: 0.11490982267455715
# Iteration: 25, Objective function value: 0.1149056669339209
# Iteration: 26, Objective function value: 0.11490548289871887
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Lu
# Iteration: 1, Objective function value: 0.5495326573898429
# Iteration: 2, Objective function value: 0.36131549865728546
# Iteration: 3, Objective function value: 0.3120815902403636
# Iteration: 4, Objective function value: 0.28921825942777196
# Iteration: 5, Objective function value: 0.2699543707504544
# Iteration: 6, Objective function value: 0.250651464493575
# Iteration: 7, Objective function value: 0.494109013207361
# Iteration: 8, Objective function value: 0.2484895507511343
# Iteration: 9, Objective function value: 0.24674171311963797
# Iteration: 10, Objective function value: 0.2390066245826325
# Iteration: 11, Objective function value: 0.47194688214159486
# Iteration: 12, Objective function value: 0.23055988785041553
# Iteration: 13, Objective function value: 0.23941851563802136
# Iteration: 14, Objective function value: 0.21978936207704375
# Iteration: 15, Objective function value: 0.20476748147661744
# Iteration: 16, Objective function value: 0.19434931280778805
# Iteration: 17, Objective function value: 0.17456352697778918
# Iteration: 18, Objective function value: 0.16561998879670314
# Iteration: 19, Objective function value: 0.16403996785287148
# Iteration: 20, Objective function value: 0.16008759156409785
# Iteration: 21, Objective function value: 0.16030822159702046
# Iteration: 22, Objective function value: 0.15915762300593855
# Iteration: 23, Objective function value: 0.15787030927994622
# Iteration: 24, Objective function value: 0.157689437945294
# Iteration: 25, Objective function value: 0.15767512081990093
# Iteration: 26, Objective function value: 0.1576726027101853
# Iteration: 27, Objective function value: 0.15766635863128006
# Iteration: 28, Objective function value: 0.15765723697771797
# Iteration: 29, Objective function value: 0.1576451662723572
# Iteration: 30, Objective function value: 0.1576496553225905
# Iteration: 31, Objective function value: 0.15764240246848019
# Iteration: 32, Objective function value: 0.15763958201266937
# Iteration: 33, Objective function value: 0.15763939603112245
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Lu
# Iteration: 1, Objective function value: 0.5394798095007297
# Iteration: 2, Objective function value: 0.3152487373378531
# Iteration: 3, Objective function value: 0.2795687045493081
# Iteration: 4, Objective function value: 0.4504646455155843
# Iteration: 5, Objective function value: 0.23628111400442534
# Iteration: 6, Objective function value: 0.21779135875635736
# Iteration: 7, Objective function value: 0.16923437450068363
# Iteration: 8, Objective function value: 0.16114192449960982
# Iteration: 9, Objective function value: 0.15865162011877382
# Iteration: 10, Objective function value: 0.15846317941817706
# Iteration: 11, Objective function value: 0.15824243378707997
# Iteration: 12, Objective function value: 0.1578772988884283
# Iteration: 13, Objective function value: 0.15775806266557518
# Iteration: 14, Objective function value: 0.1576809608257727
# Iteration: 15, Objective function value: 0.15767438823886418
# Iteration: 16, Objective function value: 0.1576710869137602
# Iteration: 17, Objective function value: 0.15765780868877574
# Iteration: 18, Objective function value: 0.1576462468420838
# Iteration: 19, Objective function value: 0.1576966640220111
# Iteration: 20, Objective function value: 0.15764479669560152
# Iteration: 21, Objective function value: 0.15763993655616265
# Iteration: 22, Objective function value: 0.15763950504050012
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Er
# Iteration: 1, Objective function value: 0.7236271885161729
# Iteration: 2, Objective function value: 0.45537603051853487
# Iteration: 3, Objective function value: 0.34857272822745033
# Iteration: 4, Objective function value: 0.18568583955480936
# Iteration: 5, Objective function value: 0.14718161079212497
# Iteration: 6, Objective function value: 0.13081854384433303
# Iteration: 7, Objective function value: 0.1301052634496569
# Iteration: 8, Objective function value: 0.12992092570732178
# Iteration: 9, Objective function value: 0.12982051467523484
# Iteration: 10, Objective function value: 0.12950534506287686
# Iteration: 11, Objective function value: 0.12914881697927252
# Iteration: 12, Objective function value: 0.1287714488851725
# Iteration: 13, Objective function value: 0.1284727535935456
# Iteration: 14, Objective function value: 0.12843048001320295
# Iteration: 15, Objective function value: 0.12842834108340279
# Iteration: 16, Objective function value: 0.12842747548450115
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Er
# Iteration: 1, Objective function value: 0.43206182900658197
# Iteration: 2, Objective function value: 0.22205685623075322
# Iteration: 3, Objective function value: 0.2041806913677014
# Iteration: 4, Objective function value: 0.17517386781001032
# Iteration: 5, Objective function value: 0.1730899030292534
# Iteration: 6, Objective function value: 0.1718592554580139
# Iteration: 7, Objective function value: 0.18641852653577615
# Iteration: 8, Objective function value: 0.16786550250007756
# Iteration: 9, Objective function value: 0.16553688725634355
# Iteration: 10, Objective function value: 0.16166026979904563
# Iteration: 11, Objective function value: 0.15855460964707763
# Iteration: 12, Objective function value: 0.15803750464464544
# Iteration: 13, Objective function value: 0.15790058941940027
# Iteration: 14, Objective function value: 0.15787686091127429
# Iteration: 15, Objective function value: 0.15782911080058787
# Iteration: 16, Objective function value: 0.1577655777184434
# Iteration: 17, Objective function value: 0.1576724016978936
# Iteration: 18, Objective function value: 0.15764047200115755
# Iteration: 19, Objective function value: 0.15758791747408005
# Iteration: 20, Objective function value: 0.1575873191362682
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Er
# Iteration: 1, Objective function value: 0.39673177104559615
# Iteration: 2, Objective function value: 0.2793892869506708
# Iteration: 3, Objective function value: 0.23164339223092184
# Iteration: 4, Objective function value: 0.20356624440587634
# Iteration: 5, Objective function value: 0.19579060860353775
# Iteration: 6, Objective function value: 0.19030461864690523
# Iteration: 7, Objective function value: 0.3019976181817465
# Iteration: 8, Objective function value: 0.18228227317510684
# Iteration: 9, Objective function value: 0.1783786478495166
# Iteration: 10, Objective function value: 0.5240048887584708
# Iteration: 11, Objective function value: 0.1775816249307714
# Iteration: 12, Objective function value: 0.17274355625840582
# Iteration: 13, Objective function value: 0.1692929085124081
# Iteration: 14, Objective function value: 0.166407282113833
# Iteration: 15, Objective function value: 0.1642773506543464
# Iteration: 16, Objective function value: 0.16019626357298272
# Iteration: 17, Objective function value: 0.15799968309945597
# Iteration: 18, Objective function value: 0.15773577429908117
# Iteration: 19, Objective function value: 0.15771168872409105
# Iteration: 20, Objective function value: 0.15770133873212314
# Iteration: 21, Objective function value: 0.15768414545671022
# Iteration: 22, Objective function value: 0.15764565309076864
# Iteration: 23, Objective function value: 0.1576057913268506
# Iteration: 24, Objective function value: 0.15762915667367575
# Iteration: 25, Objective function value: 0.1575992170116162
# Iteration: 26, Objective function value: 0.15758839508542352
# Iteration: 27, Objective function value: 0.15758733682797293
# Iteration: 28, Objective function value: 0.15758729325808757
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Er
# Iteration: 1, Objective function value: 0.6516755487634758
# Iteration: 2, Objective function value: 0.374428355136769
# Iteration: 3, Objective function value: 0.4055934327560893
# Iteration: 4, Objective function value: 0.27925581115307985
# Iteration: 5, Objective function value: 0.23015706104497102
# Iteration: 6, Objective function value: 0.22254569486169729
# Iteration: 7, Objective function value: 0.2107285419750852
# Iteration: 8, Objective function value: 0.20811084651693462
# Iteration: 9, Objective function value: 0.20574562600266302
# Iteration: 10, Objective function value: 0.20245227714807826
# Iteration: 11, Objective function value: 0.19899403272538735
# Iteration: 12, Objective function value: 0.296244269043021
# Iteration: 13, Objective function value: 0.1921332883315298
# Iteration: 14, Objective function value: 0.18392132406859515
# Iteration: 15, Objective function value: 0.18712311991985084
# Iteration: 16, Objective function value: 0.16253994259312976
# Iteration: 17, Objective function value: 0.2997072604167278
# Iteration: 18, Objective function value: 0.161351906346268
# Iteration: 19, Objective function value: 0.1559896002399065
# Iteration: 20, Objective function value: 0.15395044532389593
# Iteration: 21, Objective function value: 0.16211608200023211
# Iteration: 22, Objective function value: 0.1512998626937304
# Iteration: 23, Objective function value: 0.15057992948632237
# Iteration: 24, Objective function value: 0.15027599093478347
# Iteration: 25, Objective function value: 0.15021555883833365
# Iteration: 26, Objective function value: 0.15021196357738456
# Iteration: 27, Objective function value: 0.1502101290358236
# Iteration: 28, Objective function value: 0.1502075425944589
# Iteration: 29, Objective function value: 0.15020668431101458
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Er
# Iteration: 1, Objective function value: 0.553642756250301
# Iteration: 2, Objective function value: 0.24006770093897128
# Iteration: 3, Objective function value: 0.2058840271547678
# Iteration: 4, Objective function value: 0.19169689250298022
# Iteration: 5, Objective function value: 0.17644255180767643
# Iteration: 6, Objective function value: 0.17400463638336555
# Iteration: 7, Objective function value: 0.17302621972935248
# Iteration: 8, Objective function value: 0.1690961058766496
# Iteration: 9, Objective function value: 0.17267499364270464
# Iteration: 10, Objective function value: 0.16522960838281198
# Iteration: 11, Objective function value: 0.1621695576471938
# Iteration: 12, Objective function value: 0.15928301910699963
# Iteration: 13, Objective function value: 0.15853521179198882
# Iteration: 14, Objective function value: 0.1583677973376844
# Iteration: 15, Objective function value: 0.1583278831514092
# Iteration: 16, Objective function value: 0.15828116750885476
# Iteration: 17, Objective function value: 0.15801731420025306
# Iteration: 18, Objective function value: 0.1578221155419915
# Iteration: 19, Objective function value: 0.15765001055301414
# Iteration: 20, Objective function value: 0.15759913973456482
# Iteration: 21, Objective function value: 0.15758788533212356
# Iteration: 22, Objective function value: 0.15758737778797138
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Er
# Iteration: 1, Objective function value: 0.5050888228462865
# Iteration: 2, Objective function value: 0.2514610624598901
# Iteration: 3, Objective function value: 0.2013483979514897
# Iteration: 4, Objective function value: 0.19172302353887594
# Iteration: 5, Objective function value: 0.18540737720095624
# Iteration: 6, Objective function value: 0.18008547209969009
# Iteration: 7, Objective function value: 0.1776179697623796
# Iteration: 8, Objective function value: 0.17753105000988106
# Iteration: 9, Objective function value: 0.17751801939775974
# Iteration: 10, Objective function value: 0.17751450062385973
# Iteration: 11, Objective function value: 0.17750713086759476
# Iteration: 12, Objective function value: 0.17746467012291825
# Iteration: 13, Objective function value: 0.21716190110010042
# Iteration: 14, Objective function value: 0.17742348606168398
# Iteration: 15, Objective function value: 0.17737235242674845
# Iteration: 16, Objective function value: 0.17727474989063485
# Iteration: 17, Objective function value: 0.17736230500843736
# Iteration: 18, Objective function value: 0.17716427555731024
# Iteration: 19, Objective function value: 0.17860393006176856
# Iteration: 20, Objective function value: 0.1768134351496319
# Iteration: 21, Objective function value: 0.1753306340384
# Iteration: 22, Objective function value: 0.17079282834172113
# Iteration: 23, Objective function value: 0.16533579983409513
# Iteration: 24, Objective function value: 0.16332737689780547
# Iteration: 25, Objective function value: 0.16178426407063543
# Iteration: 26, Objective function value: 0.16089199910936297
# Iteration: 27, Objective function value: 0.1619362417929323
# Iteration: 28, Objective function value: 0.1602934335499875
# Iteration: 29, Objective function value: 0.16010332114519257
# Iteration: 30, Objective function value: 0.1600719159202541
# Iteration: 31, Objective function value: 0.1600673698518076
# Iteration: 32, Objective function value: 0.16006125973009072
# Iteration: 33, Objective function value: 0.16003662298988536
# Iteration: 34, Objective function value: 0.1599575894220174
# Iteration: 35, Objective function value: 0.23912870513331524
# Iteration: 36, Objective function value: 0.15994462003394863
# Iteration: 37, Objective function value: 0.1598993833005173
# Iteration: 38, Objective function value: 0.15971104143070114
# Iteration: 39, Objective function value: 0.18463685452846962
# Iteration: 40, Objective function value: 0.15944186709732705
# Iteration: 41, Objective function value: 0.15872358269993286
# Iteration: 42, Objective function value: 0.1578337205722546
# Iteration: 43, Objective function value: 0.1576226657879811
# Iteration: 44, Objective function value: 0.157593917959684
# Iteration: 45, Objective function value: 0.157590299211874
# Iteration: 46, Objective function value: 0.15758732218365845
# Iteration: 47, Objective function value: 0.15758730363337053
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Sc
# Iteration: 1, Objective function value: 0.5469029135659371
# Iteration: 2, Objective function value: 0.2260231716019748
# Iteration: 3, Objective function value: 0.18973823571680276
# Iteration: 4, Objective function value: 0.16738112670755642
# Iteration: 5, Objective function value: 0.22722637395984716
# Iteration: 6, Objective function value: 0.15243646037514755
# Iteration: 7, Objective function value: 0.14634039870741286
# Iteration: 8, Objective function value: 0.1423382826300633
# Iteration: 9, Objective function value: 0.14079908718690445
# Iteration: 10, Objective function value: 0.13895943075664272
# Iteration: 11, Objective function value: 0.13641137230082587
# Iteration: 12, Objective function value: 0.13475901298375612
# Iteration: 13, Objective function value: 0.13339321502680332
# Iteration: 14, Objective function value: 0.13319307394833071
# Iteration: 15, Objective function value: 0.13312831107389028
# Iteration: 16, Objective function value: 0.13311624870118755
# Iteration: 17, Objective function value: 0.13310023425077594
# Iteration: 18, Objective function value: 0.13309980055349838
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Sc
# Iteration: 1, Objective function value: 0.5463167424470784
# Iteration: 2, Objective function value: 0.2994243470240639
# Iteration: 3, Objective function value: 0.25034844778334425
# Iteration: 4, Objective function value: 0.22784907495560555
# Iteration: 5, Objective function value: 0.20177230789970876
# Iteration: 6, Objective function value: 0.19659615866848687
# Iteration: 7, Objective function value: 0.18758986813854467
# Iteration: 8, Objective function value: 0.1848041283320811
# Iteration: 9, Objective function value: 0.17960581759091773
# Iteration: 10, Objective function value: 0.1779678388648686
# Iteration: 11, Objective function value: 0.17637227124262705
# Iteration: 12, Objective function value: 0.20072891215457536
# Iteration: 13, Objective function value: 0.1719350557938402
# Iteration: 14, Objective function value: 0.1669971154558436
# Iteration: 15, Objective function value: 0.16285364978740952
# Iteration: 16, Objective function value: 0.16183580011659582
# Iteration: 17, Objective function value: 0.16138380783298167
# Iteration: 18, Objective function value: 0.16137321524582976
# Iteration: 19, Objective function value: 0.16135995879556786
# Iteration: 20, Objective function value: 0.16131303829605875
# Iteration: 21, Objective function value: 0.1612661841248154
# Iteration: 22, Objective function value: 0.16122037779809076
# Iteration: 23, Objective function value: 0.161208837668833
# Iteration: 24, Objective function value: 0.1612080011137772
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Sc
# Iteration: 1, Objective function value: 0.540013442140898
# Iteration: 2, Objective function value: 0.37667364954423366
# Iteration: 3, Objective function value: 0.3423741383230743
# Iteration: 4, Objective function value: 0.334939596449177
# Iteration: 5, Objective function value: 0.30806279436654477
# Iteration: 6, Objective function value: 0.29466197330710425
# Iteration: 7, Objective function value: 0.2758940424174444
# Iteration: 8, Objective function value: 0.2442583515832589
# Iteration: 9, Objective function value: 0.223801343018124
# Iteration: 10, Objective function value: 0.2073511524558199
# Iteration: 11, Objective function value: 0.9419631846296204
# Iteration: 12, Objective function value: 0.19558775184704075
# Iteration: 13, Objective function value: 0.18495922189877714
# Iteration: 14, Objective function value: 0.3137474538726014
# Iteration: 15, Objective function value: 0.17287581665481716
# Iteration: 16, Objective function value: 0.17345475417650813
# Iteration: 17, Objective function value: 0.16661857463123272
# Iteration: 18, Objective function value: 0.16563490640224346
# Iteration: 19, Objective function value: 0.1626073398158086
# Iteration: 20, Objective function value: 0.16240126102401137
# Iteration: 21, Objective function value: 0.1617032554651721
# Iteration: 22, Objective function value: 0.16137649448229335
# Iteration: 23, Objective function value: 0.16132183038390413
# Iteration: 24, Objective function value: 0.16123989158480062
# Iteration: 25, Objective function value: 0.16123361395306565
# Iteration: 26, Objective function value: 0.16123098051113127
# Iteration: 27, Objective function value: 0.1612273308615877
# Iteration: 28, Objective function value: 0.1612199133776223
# Iteration: 29, Objective function value: 0.16121210574256004
# Iteration: 30, Objective function value: 0.16136752370700738
# Iteration: 31, Objective function value: 0.16121149860124626
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Sc
# Iteration: 1, Objective function value: 0.56530302741324
# Iteration: 2, Objective function value: 0.4385590444774342
# Iteration: 3, Objective function value: 0.3612869853441802
# Iteration: 4, Objective function value: 0.28504648767928586
# Iteration: 5, Objective function value: 0.19113669537666247
# Iteration: 6, Objective function value: 0.17660718980528753
# Iteration: 7, Objective function value: 0.17003141698267027
# Iteration: 8, Objective function value: 0.16773253166527505
# Iteration: 9, Objective function value: 0.14931004155149938
# Iteration: 10, Objective function value: 0.6760050424173655
# Iteration: 11, Objective function value: 0.14599079204385437
# Iteration: 12, Objective function value: 0.1418438873810113
# Iteration: 13, Objective function value: 0.13826122389978837
# Iteration: 14, Objective function value: 0.13605718096207603
# Iteration: 15, Objective function value: 0.13472478014792727
# Iteration: 16, Objective function value: 0.13413835950518052
# Iteration: 17, Objective function value: 0.13336350103546066
# Iteration: 18, Objective function value: 0.13314461543181205
# Iteration: 19, Objective function value: 0.13310686046770287
# Iteration: 20, Objective function value: 0.1331018713109182
# Iteration: 21, Objective function value: 0.1330997557607768
# Iteration: 22, Objective function value: 0.13309971190243516
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Sc
# Iteration: 1, Objective function value: 0.49039222666334387
# Iteration: 2, Objective function value: 0.33227229330071156
# Iteration: 3, Objective function value: 0.2926426887624153
# Iteration: 4, Objective function value: 0.33377576228697314
# Iteration: 5, Objective function value: 0.2584814964911539
# Iteration: 6, Objective function value: 0.24263399480213024
# Iteration: 7, Objective function value: 0.22561786722073104
# Iteration: 8, Objective function value: 0.22366673808801316
# Iteration: 9, Objective function value: 0.20917491092533505
# Iteration: 10, Objective function value: 0.20518609715411493
# Iteration: 11, Objective function value: 0.20422479676524943
# Iteration: 12, Objective function value: 0.20373054793095488
# Iteration: 13, Objective function value: 0.203301486599758
# Iteration: 14, Objective function value: 0.20291992584764582
# Iteration: 15, Objective function value: 0.20264084813162508
# Iteration: 16, Objective function value: 0.1972590685403981
# Iteration: 17, Objective function value: 0.5107741088440013
# Iteration: 18, Objective function value: 0.1933305181598711
# Iteration: 19, Objective function value: 0.18974465729888576
# Iteration: 20, Objective function value: 0.23527903235766034
# Iteration: 21, Objective function value: 0.18733917065952446
# Iteration: 22, Objective function value: 0.18715278636804905
# Iteration: 23, Objective function value: 0.7155417077121098
# Iteration: 24, Objective function value: 0.18713164812903826
# Iteration: 25, Objective function value: 0.18414353036904277
# Iteration: 26, Objective function value: 0.17471792602900996
# Iteration: 27, Objective function value: 0.18499356159575925
# Iteration: 28, Objective function value: 0.16828048047263655
# Iteration: 29, Objective function value: 0.1657229453045084
# Iteration: 30, Objective function value: 0.16453405548614314
# Iteration: 31, Objective function value: 0.16250539046045565
# Iteration: 32, Objective function value: 0.1621746716623906
# Iteration: 33, Objective function value: 0.16206828860933273
# Iteration: 34, Objective function value: 0.16202151135447063
# Iteration: 35, Objective function value: 0.16185172148466048
# Iteration: 36, Objective function value: 0.16153753509752217
# Iteration: 37, Objective function value: 0.16132524491318884
# Iteration: 38, Objective function value: 0.16125259351382756
# Iteration: 39, Objective function value: 0.1612418350932308
# Iteration: 40, Objective function value: 0.16120853829983903
# Iteration: 41, Objective function value: 0.16120803507336523
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Sc
# Iteration: 1, Objective function value: 0.6532395720104625
# Iteration: 2, Objective function value: 0.3690017122084753
# Iteration: 3, Objective function value: 0.37426616734796486
# Iteration: 4, Objective function value: 0.32343614279322574
# Iteration: 5, Objective function value: 0.29780473314022077
# Iteration: 6, Objective function value: 0.5964316379373776
# Iteration: 7, Objective function value: 0.27600051435837314
# Iteration: 8, Objective function value: 0.2626400926984108
# Iteration: 9, Objective function value: 0.24027448338028456
# Iteration: 10, Objective function value: 0.22295639355412827
# Iteration: 11, Objective function value: 0.21169428724101658
# Iteration: 12, Objective function value: 0.2074273821621499
# Iteration: 13, Objective function value: 0.20431427570116023
# Iteration: 14, Objective function value: 0.20345645833935944
# Iteration: 15, Objective function value: 0.2032995560467677
# Iteration: 16, Objective function value: 0.2029882194330074
# Iteration: 17, Objective function value: 0.2027324237831713
# Iteration: 18, Objective function value: 0.19994240411184416
# Iteration: 19, Objective function value: 0.2192769393947212
# Iteration: 20, Objective function value: 0.18678190780500153
# Iteration: 21, Objective function value: 0.1845510017866095
# Iteration: 22, Objective function value: 0.5424169598969364
# Iteration: 23, Objective function value: 0.19710624089974832
# Iteration: 24, Objective function value: 0.18452710476953063
# Iteration: 25, Objective function value: 0.18360049348620006
# Iteration: 26, Objective function value: 0.17826021656558388
# Iteration: 27, Objective function value: 0.18204341737918422
# Iteration: 28, Objective function value: 0.1746468865410979
# Iteration: 29, Objective function value: 0.17319180311647814
# Iteration: 30, Objective function value: 0.1692370691847582
# Iteration: 31, Objective function value: 0.16560323684763054
# Iteration: 32, Objective function value: 0.1636579472329167
# Iteration: 33, Objective function value: 0.16359567145553533
# Iteration: 34, Objective function value: 0.1635385267205604
# Iteration: 35, Objective function value: 0.16353436567972218
# Iteration: 36, Objective function value: 0.16351429520733635
# Iteration: 37, Objective function value: 0.16345220652989279
# Iteration: 38, Objective function value: 0.16317700258291953
# Iteration: 39, Objective function value: 0.18740045359835852
# Iteration: 40, Objective function value: 0.1631348384376944
# Iteration: 41, Objective function value: 0.16292223035173867
# Iteration: 42, Objective function value: 0.16247373831901607
# Iteration: 43, Objective function value: 0.16147331635808068
# Iteration: 44, Objective function value: 0.16138737069953316
# Iteration: 45, Objective function value: 0.1612788054588667
# Iteration: 46, Objective function value: 0.1612214981678287
# Iteration: 47, Objective function value: 0.16121050964225755
# Iteration: 48, Objective function value: 0.16120837342965844
# Iteration: 49, Objective function value: 0.16120802679493612
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Ru
# Iteration: 1, Objective function value: 0.3995764282724674
# Iteration: 2, Objective function value: 0.21088516613733796
# Iteration: 3, Objective function value: 0.1801895465018654
# Iteration: 4, Objective function value: 0.15910770860873186
# Iteration: 5, Objective function value: 0.29711579009880124
# Iteration: 6, Objective function value: 0.140220146830766
# Iteration: 7, Objective function value: 0.13350485752923946
# Iteration: 8, Objective function value: 0.13283828223080626
# Iteration: 9, Objective function value: 0.13273310325451462
# Iteration: 10, Objective function value: 0.1320847134806649
# Iteration: 11, Objective function value: 0.13203402452133406
# Iteration: 12, Objective function value: 0.13171550946274577
# Iteration: 13, Objective function value: 0.13096676760120843
# Iteration: 14, Objective function value: 0.1297410155138858
# Iteration: 15, Objective function value: 0.1290444811959875
# Iteration: 16, Objective function value: 0.12898604821999288
# Iteration: 17, Objective function value: 0.12892071754784146
# Iteration: 18, Objective function value: 0.1288289778945631
# Iteration: 19, Objective function value: 0.12870874243852076
# Iteration: 20, Objective function value: 0.12915479510597977
# Iteration: 21, Objective function value: 0.1286947329247936
# Iteration: 22, Objective function value: 0.12866666189984668
# Iteration: 23, Objective function value: 0.1286655086117607
# Iteration: 24, Objective function value: 0.1286654751929004
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Ru
# Iteration: 1, Objective function value: 0.4744080233579724
# Iteration: 2, Objective function value: 0.3326841045705279
# Iteration: 3, Objective function value: 0.3085686184428548
# Iteration: 4, Objective function value: 0.27349882633273
# Iteration: 5, Objective function value: 0.41009860596285624
# Iteration: 6, Objective function value: 0.2151970637090225
# Iteration: 7, Objective function value: 0.20175562150104592
# Iteration: 8, Objective function value: 0.3114702442110028
# Iteration: 9, Objective function value: 0.2289004582321849
# Iteration: 10, Objective function value: 0.19760288985161928
# Iteration: 11, Objective function value: 0.18949433430000917
# Iteration: 12, Objective function value: 0.1849395778950302
# Iteration: 13, Objective function value: 0.1745178148089049
# Iteration: 14, Objective function value: 0.17051528900657725
# Iteration: 15, Objective function value: 0.16804392866972612
# Iteration: 16, Objective function value: 0.16623037265146934
# Iteration: 17, Objective function value: 0.4603542469870308
# Iteration: 18, Objective function value: 0.16568653237940345
# Iteration: 19, Objective function value: 0.16390490674569896
# Iteration: 20, Objective function value: 0.16342588872684577
# Iteration: 21, Objective function value: 0.16310000757180637
# Iteration: 22, Objective function value: 0.16305335605799193
# Iteration: 23, Objective function value: 0.16301913810109275
# Iteration: 24, Objective function value: 0.16301170953476182
# Iteration: 25, Objective function value: 0.16301107370109566
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Ru
# Iteration: 1, Objective function value: 0.5019142208902958
# Iteration: 2, Objective function value: 0.37780936072192395
# Iteration: 3, Objective function value: 0.32768161471193313
# Iteration: 4, Objective function value: 0.7179426239414315
# Iteration: 5, Objective function value: 0.31528504869592183
# Iteration: 6, Objective function value: 0.3894407852332485
# Iteration: 7, Objective function value: 0.29299446309870436
# Iteration: 8, Objective function value: 0.26942083842775205
# Iteration: 9, Objective function value: 0.2402547627802583
# Iteration: 10, Objective function value: 0.299920724916115
# Iteration: 11, Objective function value: 0.19966562854893885
# Iteration: 12, Objective function value: 0.2131705488734054
# Iteration: 13, Objective function value: 0.19405386585743942
# Iteration: 14, Objective function value: 0.18762258254550912
# Iteration: 15, Objective function value: 0.17979402361081526
# Iteration: 16, Objective function value: 0.18887595618837477
# Iteration: 17, Objective function value: 0.17732732426394746
# Iteration: 18, Objective function value: 0.1755429258350803
# Iteration: 19, Objective function value: 0.17299739666974306
# Iteration: 20, Objective function value: 0.17013641937701537
# Iteration: 21, Objective function value: 0.16840416455799576
# Iteration: 22, Objective function value: 0.16689817388120562
# Iteration: 23, Objective function value: 0.16551813407661536
# Iteration: 24, Objective function value: 0.16415486386642655
# Iteration: 25, Objective function value: 0.163331213199896
# Iteration: 26, Objective function value: 0.16305910243448293
# Iteration: 27, Objective function value: 0.16301541479104106
# Iteration: 28, Objective function value: 0.16301178004195854
# Iteration: 29, Objective function value: 0.16301102180725824
#
# ...
# Iteration: 30, Objective function value: 0.15284412210861956
# Iteration: 31, Objective function value: 0.15261605061550312
# Iteration: 32, Objective function value: 0.16088565855143627
# Iteration: 33, Objective function value: 0.15238545397489925
# Iteration: 34, Objective function value: 0.1523098632254794
# Iteration: 35, Objective function value: 0.2909345905602302
# Iteration: 36, Objective function value: 0.1522938830033225
# Iteration: 37, Objective function value: 0.15162873021805645
# Iteration: 38, Objective function value: 0.15101671310034648
# Iteration: 39, Objective function value: 0.1509973212335779
# Iteration: 40, Objective function value: 0.15091290981686023
# Iteration: 41, Objective function value: 0.1509053687637628
# Iteration: 42, Objective function value: 0.15089894537857612
# Iteration: 43, Objective function value: 0.15088161197441013
# Iteration: 44, Objective function value: 0.150863699769544
# Iteration: 45, Objective function value: 0.15085686699553655
# Iteration: 46, Objective function value: 0.15085567053994803
# Iteration: 47, Objective function value: 0.15085555459849914
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Re
# Iteration: 1, Objective function value: 0.5598139224851242
# Iteration: 2, Objective function value: 0.3521111345634169
# Iteration: 3, Objective function value: 0.31168719979685716
# Iteration: 4, Objective function value: 0.33249486682425017
# Iteration: 5, Objective function value: 0.273410072213909
# Iteration: 6, Objective function value: 0.25271694700621505
# Iteration: 7, Objective function value: 0.2876047040976543
# Iteration: 8, Objective function value: 0.23653313576627588
# Iteration: 9, Objective function value: 0.24025904438552623
# Iteration: 10, Objective function value: 0.23260016894865618
# Iteration: 11, Objective function value: 0.23091280185383628
# Iteration: 12, Objective function value: 0.22979420091730382
# Iteration: 13, Objective function value: 0.22922403710731584
# Iteration: 14, Objective function value: 0.22909993798072148
# Iteration: 15, Objective function value: 0.22907549824809276
# Iteration: 16, Objective function value: 0.2288172866834693
# Iteration: 17, Objective function value: 0.22356424178407952
# Iteration: 18, Objective function value: 0.2321172436202036
# Iteration: 19, Objective function value: 0.19683520657138034
# Iteration: 20, Objective function value: 0.1957527091655546
# Iteration: 21, Objective function value: 0.7828336185612339
# Iteration: 22, Objective function value: 0.1961046388825573
# Iteration: 23, Objective function value: 0.1957358085381902
# Iteration: 24, Objective function value: 0.19216300911184883
# Iteration: 25, Objective function value: 0.16186603636690236
# Iteration: 26, Objective function value: 0.15726384423200995
# Iteration: 27, Objective function value: 0.1556212908344108
# Iteration: 28, Objective function value: 0.1553654689797796
# Iteration: 29, Objective function value: 0.15523747138701402
# Iteration: 30, Objective function value: 0.15469072438714243
# Iteration: 31, Objective function value: 0.15388736035057574
# Iteration: 32, Objective function value: 0.15472757422926528
# Iteration: 33, Objective function value: 0.1532748502110979
# Iteration: 34, Objective function value: 0.1526409772854781
# Iteration: 35, Objective function value: 0.15202089509148936
# Iteration: 36, Objective function value: 0.15136010382461498
# Iteration: 37, Objective function value: 0.15343581137508347
# Iteration: 38, Objective function value: 0.1509973598702853
# Iteration: 39, Objective function value: 0.15104290742297402
# Iteration: 40, Objective function value: 0.15093474491566602
# Iteration: 41, Objective function value: 0.15091305158382207
# Iteration: 42, Objective function value: 0.15089393141350743
# Iteration: 43, Objective function value: 0.15088778036648062
# Iteration: 44, Objective function value: 0.15087001424190263
# Iteration: 45, Objective function value: 0.1508585697974722
# Iteration: 46, Objective function value: 0.15085747142356432
# Iteration: 47, Objective function value: 0.15085556604837053
# Iteration: 48, Objective function value: 0.15085555291584424
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Re
# Iteration: 1, Objective function value: 0.6259142080158736
# Iteration: 2, Objective function value: 0.32229790604261044
# Iteration: 3, Objective function value: 0.5079354703875996
# Iteration: 4, Objective function value: 0.2841373172007564
# Iteration: 5, Objective function value: 0.23473006925637613
# Iteration: 6, Objective function value: 0.21104646734133653
# Iteration: 7, Objective function value: 0.2014430575596653
# Iteration: 8, Objective function value: 0.2426543334824538
# Iteration: 9, Objective function value: 0.1877776503724195
# Iteration: 10, Objective function value: 0.17796853318168843
# Iteration: 11, Objective function value: 0.1660846797822115
# Iteration: 12, Objective function value: 0.16000503120626047
# Iteration: 13, Objective function value: 0.1581076519567503
# Iteration: 14, Objective function value: 0.1574029728021453
# Iteration: 15, Objective function value: 0.15702932765853075
# Iteration: 16, Objective function value: 0.15693723483459188
# Iteration: 17, Objective function value: 0.15692899763072848
# Iteration: 18, Objective function value: 0.15684404525434886
# Iteration: 19, Objective function value: 0.15638577213326144
# Iteration: 20, Objective function value: 0.1487359645468969
# Iteration: 21, Objective function value: 0.21014112202728086
# Iteration: 22, Objective function value: 0.14511144892645078
# Iteration: 23, Objective function value: 0.1435030713418595
# Iteration: 24, Objective function value: 1.0338147988630244
# Iteration: 25, Objective function value: 0.14348186958443268
# Iteration: 26, Objective function value: 0.1400193205066753
# Iteration: 27, Objective function value: 0.1348069734755843
# Iteration: 28, Objective function value: 0.13162711527608578
# Iteration: 29, Objective function value: 0.12936817373622903
# Iteration: 30, Objective function value: 0.12783563913847545
# Iteration: 31, Objective function value: 0.12672730596365112
# Iteration: 32, Objective function value: 0.14202416796433165
# Iteration: 33, Objective function value: 0.1256166631825751
# Iteration: 34, Objective function value: 0.12382955540552698
# Iteration: 35, Objective function value: 0.11324957895718506
# Iteration: 36, Objective function value: 0.4681568676931823
# Iteration: 37, Objective function value: 0.11234325216399828
# Iteration: 38, Objective function value: 0.10953380480367383
# Iteration: 39, Objective function value: 0.1058598056743777
# Iteration: 40, Objective function value: 0.13856017840097373
# Iteration: 41, Objective function value: 0.10511770371386878
# Iteration: 42, Objective function value: 0.10446277941437113
# Iteration: 43, Objective function value: 0.10435722557314667
# Iteration: 44, Objective function value: 0.1043373286526578
# Iteration: 45, Objective function value: 0.10429962851438412
# Iteration: 46, Objective function value: 0.10511236355949141
# Iteration: 47, Objective function value: 0.10392834101061876
# Iteration: 48, Objective function value: 0.10378430467898969
# Iteration: 49, Objective function value: 0.11919424014847377
# Iteration: 50, Objective function value: 0.10376690892456744
# Iteration: 51, Objective function value: 0.1033814319045119
# Iteration: 52, Objective function value: 0.10215303791896949
# Iteration: 53, Objective function value: 0.10280900903403829
# Iteration: 54, Objective function value: 0.10008059808923093
# Iteration: 55, Objective function value: 0.143397585875609
# Iteration: 56, Objective function value: 0.09996901372225864
# Iteration: 57, Objective function value: 0.09952930539258695
# Iteration: 58, Objective function value: 0.0993528873245437
# Iteration: 59, Objective function value: 0.09920483072866995
# Iteration: 60, Objective function value: 0.09903586138085307
# Iteration: 61, Objective function value: 0.09883844306214118
# Iteration: 62, Objective function value: 0.09875684482544604
# Iteration: 63, Objective function value: 0.09869427227267169
# Iteration: 64, Objective function value: 0.098477604858558
# Iteration: 65, Objective function value: 0.09837759935114988
# Iteration: 66, Objective function value: 0.0983556642077616
# Iteration: 67, Objective function value: 0.09838021981302879
# Iteration: 68, Objective function value: 0.09835476749867855
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Re
# Iteration: 1, Objective function value: 0.42477242569339346
# Iteration: 2, Objective function value: 0.25481905515928865
# Iteration: 3, Objective function value: 0.21917508881120323
# Iteration: 4, Objective function value: 0.1968341551761454
# Iteration: 5, Objective function value: 0.18222954501636984
# Iteration: 6, Objective function value: 0.18137499879444652
# Iteration: 7, Objective function value: 0.18015643767945516
# Iteration: 8, Objective function value: 0.1657243328210209
# Iteration: 9, Objective function value: 0.55843443437648
# Iteration: 10, Objective function value: 0.16515777174642682
# Iteration: 11, Objective function value: 0.1613380517157066
# Iteration: 12, Objective function value: 0.1575848163090707
# Iteration: 13, Objective function value: 0.15578111825594593
# Iteration: 14, Objective function value: 0.15699167680121373
# Iteration: 15, Objective function value: 0.15217724706842578
# Iteration: 16, Objective function value: 0.15184441676893817
# Iteration: 17, Objective function value: 0.15111638476031297
# Iteration: 18, Objective function value: 0.15101804156370316
# Iteration: 19, Objective function value: 0.15094823471514515
# Iteration: 20, Objective function value: 0.15091297294544007
# Iteration: 21, Objective function value: 0.1508880208892073
# Iteration: 22, Objective function value: 0.15087702236731546
# Iteration: 23, Objective function value: 0.15086162317813245
# Iteration: 24, Objective function value: 0.15085699760409493
# Iteration: 25, Objective function value: 0.15085556703283456
# Iteration: 26, Objective function value: 0.15085557545712336
# Iteration: 27, Objective function value: 0.15085555255303032
#
# feature_map_name:ZZ feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Re
# Iteration: 1, Objective function value: 0.6200072986760374
# Iteration: 2, Objective function value: 0.40815851416489285
# Iteration: 3, Objective function value: 0.6085876669597783
# Iteration: 4, Objective function value: 0.33034617485181866
# Iteration: 5, Objective function value: 0.26156833033374915
# Iteration: 6, Objective function value: 0.2229814114017974
# Iteration: 7, Objective function value: 0.20551307128081714
# Iteration: 8, Objective function value: 0.15871379686571474
# Iteration: 9, Objective function value: 0.15666238161380977
# Iteration: 10, Objective function value: 0.15566253829221172
# Iteration: 11, Objective function value: 0.15537375917966828
# Iteration: 12, Objective function value: 0.15529010445330754
# Iteration: 13, Objective function value: 0.15482713040769083
# Iteration: 14, Objective function value: 0.15413675250673733
# Iteration: 15, Objective function value: 0.15341009141773096
# Iteration: 16, Objective function value: 0.15294537708873224
# Iteration: 17, Objective function value: 0.15257519508345235
# Iteration: 18, Objective function value: 0.15234665211476797
# Iteration: 19, Objective function value: 0.15215565719020563
# Iteration: 20, Objective function value: 0.15398806108747745
# Iteration: 21, Objective function value: 0.15186756104510196
# Iteration: 22, Objective function value: 0.1522578269649791
# Iteration: 23, Objective function value: 0.15160185552870806
# Iteration: 24, Objective function value: 0.1511667820050498
# Iteration: 25, Objective function value: 0.1509749391982343
# Iteration: 26, Objective function value: 0.150908089124575
# Iteration: 27, Objective function value: 0.15088016677687727
# Iteration: 28, Objective function value: 0.15087501634938436
# Iteration: 29, Objective function value: 0.15086996527348956
# Iteration: 30, Objective function value: 0.15086085405201602
# Iteration: 31, Objective function value: 0.15085783508160355
# Iteration: 32, Objective function value: 0.15085580771851476
# Iteration: 33, Objective function value: 0.1508555562170209
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:linear element test:Tm
# Iteration: 1, Objective function value: 0.7481047999336775
# Iteration: 2, Objective function value: 0.5397275364405875
# Iteration: 3, Objective function value: 0.481362721923227
# Iteration: 4, Objective function value: 0.35665528905281274
# Iteration: 5, Objective function value: 0.2718424952401966
# Iteration: 6, Objective function value: 0.2169951164216329
# Iteration: 7, Objective function value: 0.3068760139850909
# Iteration: 8, Objective function value: 0.17266670415033467
# Iteration: 9, Objective function value: 0.15829314429096414
# Iteration: 10, Objective function value: 0.15595277179172834
# Iteration: 11, Objective function value: 0.1546264000365686
# Iteration: 12, Objective function value: 0.15233113993012945
# Iteration: 13, Objective function value: 0.1509181426696513
# Iteration: 14, Objective function value: 0.14926777777287265
# Iteration: 15, Objective function value: 0.1484867800269984
# Iteration: 16, Objective function value: 0.14813694602593383
# Iteration: 17, Objective function value: 0.14788840932821135
# Iteration: 18, Objective function value: 0.1476926292302015
# Iteration: 19, Objective function value: 0.1476322792184359
# Iteration: 20, Objective function value: 0.14749229686240847
# Iteration: 21, Objective function value: 0.19671983193426373
# Iteration: 22, Objective function value: 0.14735437289002112
# Iteration: 23, Objective function value: 0.147571803478554
# Iteration: 24, Objective function value: 0.14721225864298068
# Iteration: 25, Objective function value: 0.14719869318193027
# Iteration: 26, Objective function value: 0.14717287279364888
# Iteration: 27, Objective function value: 0.1471660846093263
# Iteration: 28, Objective function value: 0.14716517496984655
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:full element test:Tm
# Iteration: 1, Objective function value: 0.6212067848875369
# Iteration: 2, Objective function value: 0.43615870014083163
# Iteration: 3, Objective function value: 0.8450909194037891
# Iteration: 4, Objective function value: 0.5596239453882428
# Iteration: 5, Objective function value: 0.3742829650407588
# Iteration: 6, Objective function value: 0.3227057823610894
# Iteration: 7, Objective function value: 0.6188313847982955
# Iteration: 8, Objective function value: 0.28470976071385357
# Iteration: 9, Objective function value: 0.43446093721598567
# Iteration: 10, Objective function value: 0.23867080952086933
# Iteration: 11, Objective function value: 0.18818758322122003
# Iteration: 12, Objective function value: 0.16707274112558446
# Iteration: 13, Objective function value: 0.16196156892240207
# Iteration: 14, Objective function value: 0.16144251791491196
# Iteration: 15, Objective function value: 0.16070420894501145
# Iteration: 16, Objective function value: 0.16034204558294438
# Iteration: 17, Objective function value: 0.15990757018782759
# Iteration: 18, Objective function value: 0.15984369105304574
# Iteration: 19, Objective function value: 0.15983128721050793
# Iteration: 20, Objective function value: 0.15983065936511387
#
# feature_map_name:Pauli feature_map_reps:1 ansatz_reps:1 entanglement:circular element test:Tm
# Iteration: 1, Objective function value: 0.543834261839384
# Iteration: 2, Objective function value: 0.3102315230883087
# Iteration: 3, Objective function value: 0.3077489663760961
# Iteration: 4, Objective function value: 0.256090001762176
# Iteration: 5, Objective function value: 0.2510837780844842
# Iteration: 6, Objective function value: 0.24599121000393645
# Iteration: 7, Objective function value: 0.22505339970255167
# Iteration: 8, Objective function value: 0.6995581149712069
# Iteration: 9, Objective function value: 0.4769076664066792
# Iteration: 10, Objective function value: 0.21972715282661032
# Iteration: 11, Objective function value: 0.20718273062799614
# Iteration: 12, Objective function value: 0.19946414040134675
